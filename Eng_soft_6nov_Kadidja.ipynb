# %% [markdown]
# <a href="https://colab.research.google.com/github/SabrinaRib/tecnica_progamacao/blob/main/Eng_soft_6nov_Kadidja.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introdução a Python

# %% [markdown]
# TAREFA 1:
# Faça um programa que leia dois números
# inteiros e exiba a soma deles.

# %%
a=(int(input("Informe o primeiro numero:")))
b=(int(input("Informe o segundo numero:")))
print("O resultado é:" ,a+b)
# Out:
# Informe o primeiro numero:7
# Informe o segundo numero:3
# O resultado é: 10

# %% [markdown]
# TAREFA 2:
# Faça um programa que leia a nota que um
# aluno tirou em P1(Prova 1) e P2(Prova 2)

# %%
P1=(float(input("Informe a primeira nota:")))
P2=(float(input("Informe a segunda nota:")))
media=((P1+P2)//2)
print("A media é:" ,media)
if media >=6:
  print("Aluno aprovado :)")
else:
  print("Aluno reprovado :(")
# Out:
# Informe a primeira nota:4
# Informe a segunda nota:1
# A media é: 2.0
# Aluno reprovado :(

# %% [markdown]
# TAREFA 3:
# Leia um nome armazenado em uma variável
# e imprima

# %%
nome=input("Digite seu nome:")
print("Ola" ,nome)
# Out:
# Digite seu nome:Sabrina
# Ola Sabrina

# %% [markdown]
# TAREFA 4:
# Solicite que o usuário digite seu nome.
# Solicite que o usuários digite seu ano de nascimento (formato AAAA).

# %%
nome=input("Digite seu nome:")
data=int(input("Digite sua data de nascimento (AAAA):"))
print(f"{nome} nasceu em {data}")
# Out:
# Digite seu nome:Sabrina
# Digite sua data de nascimento (AAAA):2006
# Sabrina nasceu em 2006

# %% [markdown]
# TAREFA 5:
# Solicite que o usuário digite seu nome e sua idade.
#
# Imprima “Olá, nome! Você tem idade anos?”
#
# Imprima o ano de nascimento da pessoa (ignore meses e dias)
#
# Imprima o nome da pessoa idade vezes (João tem 18, imprime JoãoJoão...)

# %%
nome=input("Digite seu nome:")
ano=(int(input("Digite seu ano de nascimento:")))
idade=(int(input("Digite sua idade:")))
print(f"Olá, {nome}! Você tem {idade} anos?")
print(f"Seu ano de nascimento é:{ano}")
print(nome * idade)
# Out:
# Digite seu nome:Sabrina
# Digite seu ano de nascimento:2006
# Digite sua idade:18
# Olá, Sabrina! Você tem 18 anos?
# Seu ano de nascimento é:2006
# SabrinaSabrinaSabrinaSabrinaSabrinaSabrinaSabrinaSabrinaSabrinaSabrinaSabrinaSabrinaSabrinaSabrinaSabrinaSabrinaSabrinaSabrina

# %% [markdown]
# TAREFA 6: Solicite ao usuário que digite três notas
# depois calcule e exiba a média ponderada.

# %%
nota1=float(input("Digite a primeira nota:"))
nota2=float(input("Digite a segunda nota:"))
nota3=float(input("Digite a terceira nota:"))
media_ponderada=(nota1+nota2+nota3)//3
print("A media ponderada das três notas é:" ,media_ponderada)
# Out:
# Digite a primeira nota:8.0
# Digite a segunda nota:1.0
# Digite a terceira nota:2.0
# A media ponderada das três notas é: 3.0

# %% [markdown]
# TEREFA 7: Solicite ao usuário três notas e seus
# respectivos pesos, depois calcule e exiba a
# média ponderada.

# %%
nota1=float(input("Digite a primeira nota:"))
peso1=float(input("Digite o peso da primeira nota:"))
nota2=float(input("Digite a segunda nota:"))
peso2=float(input("Digite o peso da segunda nota:"))
nota3=float(input("Digite a terceira nota:"))
peso3=float(input("Digite o peso da terceira nota:"))
media_ponderada=((nota1*peso1)+(nota2*peso2)+(nota3*peso3))//(peso1+peso2+peso3)
print("A media ponderada das três notas é:" ,media_ponderada)
# Out:
# Digite a primeira nota:8
# Digite o peso da primeira nota:2
# Digite a segunda nota:7
# Digite o peso da segunda nota:3
# Digite a terceira nota:9
# Digite o peso da terceira nota:5
# A media ponderada das três notas é: 8.0

# %% [markdown]
# TEREFA 8: Peça ao usuário um número e exiba a soma
# de seus dígitos.

# %%
num=input("Digite um numero:")
soma=0
for digito in num:
  soma+=int(digito)
print("A soma dos digitos é:" ,soma)
# Out:
# Digite um numero:1234
# A soma dos digitos é: 10

# %% [markdown]
# TAREFA 9: Peça ao usuário uma palavra e exiba-a
# invertida sem usar laços.

# %%
palavra=input("Digite uma palavra:")
palavra_invertida=palavra[::-1]
print("A palavra invertida é:" ,palavra_invertida)
# Out:
# Digite uma palavra:celular
# A palavra invertida é: ralulec
